# %%
import pandas as pd
import numpy as np
df = pd.read_csv('\\Stars Predition\\dataset\\Amazon_Unlocked_Mobile.csv')
df = df.head(500)
df = df[["Reviews","Rating","Product Name"]]
df = df.reset_index()
df
# Out:
#      index                                            Reviews  Rating  \
# 0        0  I feel so LUCKY to have found this used (phone...       5
# 1        1  nice phone, nice up grade from my pantach revu...       4
# 2        2                                       Very pleased       5
# 3        3  It works good but it goes slow sometimes but i...       4
# 4        4  Great phone to replace my lost phone. The only...       4
# ..     ...                                                ...     ...
# 495    495  good phone with a top hardware and relative lo...       5
# 496    496  Like phone its nice for price sometimes it get...       5
# 497    497             So to be put to use by the beneficiary       4
# 498    498  Attractive phone but did not work upon arrival...       1
# 499    499  This phone works well as how it supposed to be...       5
#
#                                           Product Name
# 0    "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 1    "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 2    "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 3    "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 4    "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# ..                                                 ...
# 495  4G-Unlocked Huawei Honor 6 5.0 TFT LTPS Screen...
# 496  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
# 497  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
# 498  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
# 499  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
#
# [500 rows x 4 columns]

# %% [markdown]
# The data we'll use consists of only three columns; the product name is not crucial. We've selected only 500 samples from the entire dataset. Following that, we'll import the VADER analyzer, an acronym for Valence Aware Dictionary and Sentiment Reasoner. This will provide us with four values {'neg','neu','pos','compound'} based on the analysis of each word, assigning it a score between -1 and 1.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
res = {}
for i, row in tqdm(df.iterrows(),total=len(df)):
    text = row['Reviews']
    index = row['index']
    res[index] = sia.polarity_scores(text) #output of polarity_scores() : {'neg','neu','pos','compound'}
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index()
vaders = vaders.merge(df,how='left').drop(['neg','neu','pos'],axis=1)
vaders
# Out:
#      index  compound                                            Reviews  \
# 0        0    0.8783  I feel so LUCKY to have found this used (phone...
# 1        1    0.9231  nice phone, nice up grade from my pantach revu...
# 2        2    0.4927                                       Very pleased
# 3        3    0.9185  It works good but it goes slow sometimes but i...
# 4        4    0.2942  Great phone to replace my lost phone. The only...
# ..     ...       ...                                                ...
# 495    495    0.3818  good phone with a top hardware and relative lo...
# 496    496    0.8069  Like phone its nice for price sometimes it get...
# 497    497    0.4767             So to be put to use by the beneficiary
# 498    498   -0.1815  Attractive phone but did not work upon arrival...
# 499    499    0.9943  This phone works well as how it supposed to be...
#
#      Rating                                       Product Name
# 0         5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 1         4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 2         5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 3         4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 4         4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# ..      ...                                                ...
# 495       5  4G-Unlocked Huawei Honor 6 5.0 TFT LTPS Screen...
# 496       5  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
# 497       4  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
# 498       1  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
# 499       5  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
#
# [500 rows x 5 columns]

# %% [markdown]
# We have excluded 'neg,' 'neu,' and 'pos' scores, focusing solely on the 'compound' score. The data will be categorized into the following intervals for sorting:
#
# * [ -1, -0.5) : 1 Star
#
# * [-0.5, 0) : 2 Stars
#
# * [0] : 3 Stars
#
# * (0, 0.5) : 4 Stars
#
# * [0.5, 1] : 5 Stars

# %%
rate_value = []
for i in range(len(vaders)):
    rvalue = vaders['compound'][i]
    if(rvalue<=1 and rvalue>=0.5):
        rate_value.append('5 Stars')
    elif(rvalue<0.5 and rvalue>0):
        rate_value.append('4 Stars')
    elif(rvalue==0):
        rate_value.append('3 Stars')
    elif(rvalue<0 and rvalue>=-0.5):
        rate_value.append('2 Stars')
    else:
        rate_value.append('1 Star')
rate_value=pd.DataFrame(rate_value).rename(columns={0:'Predicted Stars'})
rate_value
# Out:
#     Predicted Stars
# 0           5 Stars
# 1           5 Stars
# 2           4 Stars
# 3           5 Stars
# 4           4 Stars
# ..              ...
# 495         4 Stars
# 496         5 Stars
# 497         4 Stars
# 498         2 Stars
# 499         5 Stars
#
# [500 rows x 1 columns]

# %%
results = pd.DataFrame(rate_value).reset_index()
results = results.merge(vaders,how='left').drop(['compound'],axis=1)
results
# Out:
#      index Predicted Stars                                            Reviews  \
# 0        0         5 Stars  I feel so LUCKY to have found this used (phone...
# 1        1         5 Stars  nice phone, nice up grade from my pantach revu...
# 2        2         4 Stars                                       Very pleased
# 3        3         5 Stars  It works good but it goes slow sometimes but i...
# 4        4         4 Stars  Great phone to replace my lost phone. The only...
# ..     ...             ...                                                ...
# 495    495         4 Stars  good phone with a top hardware and relative lo...
# 496    496         5 Stars  Like phone its nice for price sometimes it get...
# 497    497         4 Stars             So to be put to use by the beneficiary
# 498    498         2 Stars  Attractive phone but did not work upon arrival...
# 499    499         5 Stars  This phone works well as how it supposed to be...
#
#      Rating                                       Product Name
# 0         5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 1         4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 2         5  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 3         4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# 4         4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...
# ..      ...                                                ...
# 495       5  4G-Unlocked Huawei Honor 6 5.0 TFT LTPS Screen...
# 496       5  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
# 497       4  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
# 498       1  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
# 499       5  5.0" Cell Phones Unlocked Android 5.1 MTK6580 ...
#
# [500 rows x 5 columns]

# %% [markdown]
# in the final resultes we can see the preictoins we made and the real rating the accuracy may not be the best but it considered very good!.
